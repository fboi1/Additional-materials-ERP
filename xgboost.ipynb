# %% [markdown]
# # Fit the XGBoost model

# %%
import pandas as pd
import numpy as np
from glob import glob
import os
import joblib
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, TimeSeriesSplit
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

def get_xgboost_param_grid():
    """
    Define hyperparameter grid for XGBoost optimization.
    """
    param_grid = {
        'n_estimators': [100, 200, 300, 500, 600, 800],
        'max_depth': [3, 4, 5, 6, 7, 8],
        'learning_rate': [0.01, 0.05, 0.1, 0.2],
        'subsample': [0.8, 0.9, 1.0],
        'colsample_bytree': [0.8, 0.9, 1.0],
        'reg_alpha': [0, 0.1, 0.5, 1.0],
        'reg_lambda': [0, 0.1, 0.5, 1.0],
        'min_child_weight': [1, 3, 5],
        'gamma': [0, 0.1, 0.2]
    }
    return param_grid

def plot_feature_importance(model, feature_names, stock_name, save_path=None, top_n=20):
    """
    Plot feature importance from XGBoost model.
    """
    # Get feature importance
    importance_df = pd.DataFrame({
        'feature': feature_names,
        'importance': model.feature_importances_
    }).sort_values('importance', ascending=False)
    
    # Plot top N features
    plt.figure(figsize=(12, 8))
    top_features = importance_df.head(top_n)
    
    sns.barplot(data=top_features, x='importance', y='feature', palette='viridis')
    plt.title(f'{stock_name} - Top {top_n} Feature Importance (XGBoost)')
    plt.xlabel('Feature Importance')
    plt.ylabel('Features')
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Feature importance plot saved to {save_path}")
    
    plt.show()
    
    return importance_df

def plot_confusion_matrix(y_true, y_pred, stock_name, save_path=None):
    """
    Plot confusion matrix.
    """
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Down', 'Up'], yticklabels=['Down', 'Up'])
    plt.title(f'{stock_name} - Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Confusion matrix saved to {save_path}")
    
    plt.show()

# Paths
input_folder = "data/processed/stock_data"
summary_folder = "summary"
model_folder = os.path.join(summary_folder, "xgboost2")
plots_folder = os.path.join(summary_folder, "xgboost_plots2")
os.makedirs(model_folder, exist_ok=True)
os.makedirs(plots_folder, exist_ok=True)

summary_results = []
feature_importance_results = []

# XGBoost hyperparameter search configuration
RANDOM_SEARCH_ITERATIONS = 50  # Reduce for faster execution
CV_FOLDS = 5
RANDOM_STATE = 42

for file_path in glob(os.path.join(input_folder, "*.csv")):
    stock_name = os.path.basename(file_path).replace("_features.csv", "")
    print(f"\n{'='*60}")
    print(f"Processing {stock_name}")
    print(f"{'='*60}")

    try:
        # Load data
        df = pd.read_csv(file_path)
        df.dropna(inplace=True)

        # Create binary target: 1 if price goes up tomorrow, 0 if down
        df['Direction'] = (df['Close'].shift(-1) > df['Close']).astype(int)
        df.dropna(inplace=True)

        # Features
        X = df.drop(columns=[
            "Date","Close","Target","Direction",
            "High","Low","Open","High_lag1","Low_lag1","Open_lag1"
        ])
        y = df['Direction']

        print(f"Dataset shape: {X.shape}")
        print(f"Class distribution: {y.value_counts().to_dict()}")
        print(f"Class balance: {y.mean():.3f} positive class ratio")

        # Split data (time series aware)
        train_size = int(len(X) * 0.8)
        X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
        y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

        print(f"Train size: {len(X_train)}, Test size: {len(X_test)}")

        # Optional: Scale features (XGBoost doesn't strictly need it, but can help)
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)

        # Convert to DMatrix for XGBoost (more efficient)
        dtrain = xgb.DMatrix(X_train_scaled, label=y_train, feature_names=X.columns.tolist())
        dtest = xgb.DMatrix(X_test_scaled, label=y_test, feature_names=X.columns.tolist())

        # Base XGBoost model
        base_xgb = xgb.XGBClassifier(
            objective='binary:logistic',
            eval_metric='auc',
            random_state=RANDOM_STATE,
            n_jobs=-1,
            verbosity=0
        )

        # Hyperparameter tuning with RandomizedSearchCV
        print(f"Starting hyperparameter tuning with {RANDOM_SEARCH_ITERATIONS} iterations...")
        
        # Use TimeSeriesSplit for time series data
        tscv = TimeSeriesSplit(n_splits=CV_FOLDS)
        
        param_grid = get_xgboost_param_grid()
        
        random_search = RandomizedSearchCV(
            estimator=base_xgb,
            param_distributions=param_grid,
            n_iter=RANDOM_SEARCH_ITERATIONS,
            cv=tscv,
            scoring='roc_auc',
            n_jobs=-1,
            random_state=RANDOM_STATE,
            verbose=0
        )

        # Fit the random search
        random_search.fit(X_train_scaled, y_train)
        
        # Get best model
        best_xgb = random_search.best_estimator_
        
        print(f"Best parameters found:")
        for param, value in random_search.best_params_.items():
            print(f"  {param}: {value}")
        print(f"Best CV AUC: {random_search.best_score_:.4f}")

        # Make predictions
        y_pred = best_xgb.predict(X_test_scaled)
        y_proba = best_xgb.predict_proba(X_test_scaled)[:, 1]

        # Calculate metrics
        acc = accuracy_score(y_test, y_pred)
        auc = roc_auc_score(y_test, y_proba)
        
        print(f"\n--- MODEL PERFORMANCE ---")
        print(f"XGBoost Accuracy: {acc:.4f}")
        print(f"XGBoost AUC: {auc:.4f}")
        print(f"Best CV AUC: {random_search.best_score_:.4f}")
        print("\nClassification Report:")
        print(classification_report(y_test, y_pred))

        # Feature importance analysis
        feature_importance_df = plot_feature_importance(
            best_xgb, X.columns.tolist(), stock_name, 
            save_path=os.path.join(plots_folder, f"{stock_name}_feature_importance.png")
        )
        
        # Plot confusion matrix
        plot_confusion_matrix(
            y_test, y_pred, stock_name,
            save_path=os.path.join(plots_folder, f"{stock_name}_confusion_matrix.png")
        )

        # Save model and scaler
        model_path = os.path.join(model_folder, f"{stock_name}_xgboost_model.pkl")
        scaler_path = os.path.join(model_folder, f"{stock_name}_scaler.pkl")
        params_path = os.path.join(model_folder, f"{stock_name}_best_params.pkl")
        
        joblib.dump(best_xgb, model_path)
        joblib.dump(scaler, scaler_path)
        joblib.dump(random_search.best_params_, params_path)
        
        print(f"Saved model to {model_path}")
        print(f"Saved scaler to {scaler_path}")
        print(f"Saved best parameters to {params_path}")

        # Store top 10 most important features for this stock
        top_features = feature_importance_df.head(10)
        for idx, row in top_features.iterrows():
            feature_importance_results.append({
                'Stock': stock_name,
                'Feature': row['feature'],
                'Importance': row['importance'],
                'Rank': idx + 1
            })

        # Append metrics to summary
        summary_results.append({
            "Stock": stock_name,
            "Accuracy": acc,
            "AUC": auc,
            "CV_AUC": random_search.best_score_,
            "N_Features": X.shape[1],
            "Train_Size": len(X_train),
            "Test_Size": len(X_test),
            "Class_Balance": y.mean(),
            "Best_N_Estimators": random_search.best_params_.get('n_estimators', 'N/A'),
            "Best_Max_Depth": random_search.best_params_.get('max_depth', 'N/A'),
            "Best_Learning_Rate": random_search.best_params_.get('learning_rate', 'N/A')
        })

    except Exception as e:
        print(f"Error processing {stock_name}: {str(e)}")
        continue

# Save summary results
summary_df = pd.DataFrame(summary_results)
summary_file = os.path.join(summary_folder, "stock_data_model_summary_xgboost.csv")
summary_df.to_csv(summary_file, index=False)
print(f"\nSummary saved to {summary_file}")

# Save feature importance results
feature_importance_df = pd.DataFrame(feature_importance_results)
feature_importance_file = os.path.join(summary_folder, "stock_data_feature_importance_xgboost.csv")
feature_importance_df.to_csv(feature_importance_file, index=False)
print(f"Feature importance results saved to {feature_importance_file}")

# Print overall summary
print(f"\n{'='*80}")
print("OVERALL XGBOOST MODEL SUMMARY")
print(f"{'='*80}")
print(f"Total stocks processed: {len(summary_results)}")
print(f"Average Accuracy: {summary_df['Accuracy'].mean():.4f} ± {summary_df['Accuracy'].std():.4f}")
print(f"Average AUC: {summary_df['AUC'].mean():.4f} ± {summary_df['AUC'].std():.4f}")
print(f"Average CV AUC: {summary_df['CV_AUC'].mean():.4f} ± {summary_df['CV_AUC'].std():.4f}")
print(f"Best performing stock (AUC): {summary_df.loc[summary_df['AUC'].idxmax(), 'Stock']} ({summary_df['AUC'].max():.4f})")
print(f"Models with AUC > 0.55: {sum(summary_df['AUC'] > 0.55)}/{len(summary_results)}")

# Most common important features across all stocks
print(f"\nMOST IMPORTANT FEATURES ACROSS ALL STOCKS:")
top_features_overall = feature_importance_df.groupby('Feature')['Importance'].agg(['count', 'mean', 'std']).sort_values('mean', ascending=False)
print(top_features_overall.head(10))

# Create summary plots
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.hist(summary_df['Accuracy'], bins=15, alpha=0.7, color='skyblue', edgecolor='black')
plt.axvline(summary_df['Accuracy'].mean(), color='red', linestyle='--', label=f'Mean: {summary_df["Accuracy"].mean():.3f}')
plt.xlabel('Accuracy')
plt.ylabel('Frequency')
plt.title('Distribution of Model Accuracies')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 2)
plt.hist(summary_df['AUC'], bins=15, alpha=0.7, color='lightcoral', edgecolor='black')
plt.axvline(summary_df['AUC'].mean(), color='red', linestyle='--', label=f'Mean: {summary_df["AUC"].mean():.3f}')
plt.xlabel('AUC')
plt.ylabel('Frequency')
plt.title('Distribution of Model AUCs')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 3)
plt.scatter(summary_df['Accuracy'], summary_df['AUC'], alpha=0.6, s=50)
plt.xlabel('Accuracy')
plt.ylabel('AUC')
plt.title('Accuracy vs AUC')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(plots_folder, 'overall_model_performance.png'), dpi=300, bbox_inches='tight')
plt.show()

print(f"\nAll plots saved to {plots_folder}")
print("XGBoost model training completed!")
# Out:
# ============================================================
# Processing AAPL_daily
# ============================================================
# Dataset shape: (11224, 17)
# Class distribution: {0: 5619, 1: 5605}
# Class balance: 0.499 positive class ratio
# Train size: 8979, Test size: 2245
# Starting hyperparameter tuning with 50 iterations...
# Best parameters found:
#   subsample: 0.9
#   reg_lambda: 0.5
#   reg_alpha: 1.0
#   n_estimators: 100
#   min_child_weight: 1
#   max_depth: 3
#   learning_rate: 0.05
#   gamma: 0
#   colsample_bytree: 0.9
# Best CV AUC: 0.5294
#
# --- MODEL PERFORMANCE ---
# XGBoost Accuracy: 0.4833
# XGBoost AUC: 0.5111
# Best CV AUC: 0.5294
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.47      0.89      0.61      1040
#            1       0.58      0.14      0.22      1205
#
#     accuracy                           0.48      2245
#    macro avg       0.52      0.51      0.42      2245
# weighted avg       0.53      0.48      0.40      2245
#
# Feature importance plot saved to summary\xgboost_plots2\AAPL_daily_feature_importance.png
# Confusion matrix saved to summary\xgboost_plots2\AAPL_daily_confusion_matrix.png
# Saved model to summary\xgboost2\AAPL_daily_xgboost_model.pkl
# Saved scaler to summary\xgboost2\AAPL_daily_scaler.pkl
# Saved best parameters to summary\xgboost2\AAPL_daily_best_params.pkl
#
# ============================================================
# Processing GE_daily
# ============================================================
# Dataset shape: (15977, 17)
# Class distribution: {0: 8221, 1: 7756}
# Class balance: 0.485 positive class ratio
# Train size: 12781, Test size: 3196
# Starting hyperparameter tuning with 50 iterations...
# Best parameters found:
#   subsample: 0.9
#   reg_lambda: 1.0
#   reg_alpha: 1.0
#   n_estimators: 200
#   min_child_weight: 5
#   max_depth: 4
#   learning_rate: 0.01
#   gamma: 0.1
#   colsample_bytree: 0.9
# Best CV AUC: 0.5240
#
# --- MODEL PERFORMANCE ---
# XGBoost Accuracy: 0.4822
# XGBoost AUC: 0.4760
# Best CV AUC: 0.5240
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.63      0.55      1582
#            1       0.48      0.34      0.40      1614
#
#     accuracy                           0.48      3196
#    macro avg       0.48      0.48      0.47      3196
# weighted avg       0.48      0.48      0.47      3196
#
# Feature importance plot saved to summary\xgboost_plots2\GE_daily_feature_importance.png
# Confusion matrix saved to summary\xgboost_plots2\GE_daily_confusion_matrix.png
# Saved model to summary\xgboost2\GE_daily_xgboost_model.pkl
# Saved scaler to summary\xgboost2\GE_daily_scaler.pkl
# Saved best parameters to summary\xgboost2\GE_daily_best_params.pkl
#
# ============================================================
# Processing IBM_daily
# ============================================================
# Dataset shape: (15975, 17)
# Class distribution: {0: 8047, 1: 7928}
# Class balance: 0.496 positive class ratio
# Train size: 12780, Test size: 3195
# Starting hyperparameter tuning with 50 iterations...
# Best parameters found:
#   subsample: 0.8
#   reg_lambda: 1.0
#   reg_alpha: 1.0
#   n_estimators: 200
#   min_child_weight: 1
#   max_depth: 4
#   learning_rate: 0.01
#   gamma: 0.2
#   colsample_bytree: 1.0
# Best CV AUC: 0.5200
#
# --- MODEL PERFORMANCE ---
# XGBoost Accuracy: 0.4948
# XGBoost AUC: 0.4920
# Best CV AUC: 0.5200
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      0.38      0.42      1524
#            1       0.51      0.60      0.55      1671
#
#     accuracy                           0.49      3195
#    macro avg       0.49      0.49      0.49      3195
# weighted avg       0.49      0.49      0.49      3195
#
# Feature importance plot saved to summary\xgboost_plots2\IBM_daily_feature_importance.png
# Confusion matrix saved to summary\xgboost_plots2\IBM_daily_confusion_matrix.png
# Saved model to summary\xgboost2\IBM_daily_xgboost_model.pkl
# Saved scaler to summary\xgboost2\IBM_daily_scaler.pkl
# Saved best parameters to summary\xgboost2\IBM_daily_best_params.pkl
#
# ============================================================
# Processing JNJ_daily
# ============================================================
# Dataset shape: (15968, 17)
# Class distribution: {0: 8158, 1: 7810}
# Class balance: 0.489 positive class ratio
# Train size: 12774, Test size: 3194
# Starting hyperparameter tuning with 50 iterations...
# Best parameters found:
#   subsample: 0.8
#   reg_lambda: 1.0
#   reg_alpha: 1.0
#   n_estimators: 200
#   min_child_weight: 1
#   max_depth: 4
#   learning_rate: 0.01
#   gamma: 0.2
#   colsample_bytree: 1.0
# Best CV AUC: 0.5292
#
# --- MODEL PERFORMANCE ---
# XGBoost Accuracy: 0.4800
# XGBoost AUC: 0.4974
# Best CV AUC: 0.5292
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.47      0.77      0.59      1518
#            1       0.51      0.21      0.30      1676
#
#     accuracy                           0.48      3194
#    macro avg       0.49      0.49      0.44      3194
# weighted avg       0.49      0.48      0.44      3194
#
# Feature importance plot saved to summary\xgboost_plots2\JNJ_daily_feature_importance.png
# Confusion matrix saved to summary\xgboost_plots2\JNJ_daily_confusion_matrix.png
# Saved model to summary\xgboost2\JNJ_daily_xgboost_model.pkl
# Saved scaler to summary\xgboost2\JNJ_daily_scaler.pkl
# Saved best parameters to summary\xgboost2\JNJ_daily_best_params.pkl
#
# ============================================================
# Processing MSFT_daily
# ============================================================
# Dataset shape: (9899, 17)
# Class distribution: {1: 5021, 0: 4878}
# Class balance: 0.507 positive class ratio
# Train size: 7919, Test size: 1980
# Starting hyperparameter tuning with 50 iterations...
# Best parameters found:
#   subsample: 0.8
#   reg_lambda: 1.0
#   reg_alpha: 1.0
#   n_estimators: 200
#   min_child_weight: 1
#   max_depth: 4
#   learning_rate: 0.01
#   gamma: 0.2
#   colsample_bytree: 1.0
# Best CV AUC: 0.5202
#
# --- MODEL PERFORMANCE ---
# XGBoost Accuracy: 0.5222
# XGBoost AUC: 0.5370
# Best CV AUC: 0.5202
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.59      0.53       903
#            1       0.57      0.47      0.52      1077
#
#     accuracy                           0.52      1980
#    macro avg       0.53      0.53      0.52      1980
# weighted avg       0.53      0.52      0.52      1980
#
# Feature importance plot saved to summary\xgboost_plots2\MSFT_daily_feature_importance.png
# Confusion matrix saved to summary\xgboost_plots2\MSFT_daily_confusion_matrix.png
# Saved model to summary\xgboost2\MSFT_daily_xgboost_model.pkl
# Saved scaler to summary\xgboost2\MSFT_daily_scaler.pkl
# Saved best parameters to summary\xgboost2\MSFT_daily_best_params.pkl
#
# Summary saved to summary\stock_data_model_summary_xgboost.csv
# Feature importance results saved to summary\stock_data_feature_importance_xgboost.csv
#
# ================================================================================
# OVERALL XGBOOST MODEL SUMMARY
# ================================================================================
# Total stocks processed: 5
# Average Accuracy: 0.4925 ± 0.0176
# Average AUC: 0.5027 ± 0.0229
# Average CV AUC: 0.5246 ± 0.0046
# Best performing stock (AUC): MSFT_daily (0.5370)
# Models with AUC > 0.55: 0/5
#
# MOST IMPORTANT FEATURES ACROSS ALL STOCKS:
#                  count      mean       std
# Feature
# SMA_5                5  0.069642  0.016702
# Log_Return_lag1      2  0.067588  0.000588
# BB_upper             4  0.066126  0.004779
# BB_lower             3  0.065959  0.004522
# EMA_10               4  0.065609  0.008303
# Stoch_%D_14          3  0.063945  0.006125
# Log_Return           5  0.063580  0.004507
# SMA_10               3  0.062113  0.003952
# Stoch_%K_14          5  0.060785  0.002375
# MACD                 2  0.060308  0.003695
# All plots saved to summary\xgboost_plots2
# XGBoost model training completed!

# %% [markdown]
# # Test the XGBoost model

# %%
import pandas as pd
import numpy as np
from glob import glob
import os
import joblib
import xgboost as xgb
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, log_loss, precision_score, recall_score, f1_score
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

def monte_carlo_permutation_test_xgboost(X_train, X_test, y_train, y_test, 
                                        best_params=None, n_permutations=1000, 
                                        random_state=42, use_cv=True):
    """
    Perform Monte Carlo permutation test for XGBoost model.
    
    Parameters:
    -----------
    X_train, X_test : array-like
        Training and testing features
    y_train, y_test : array-like
        Training and testing labels
    best_params : dict
        Best hyperparameters found from tuning
    n_permutations : int
        Number of permutations for the test
    random_state : int
        Random seed for reproducibility
    use_cv : bool
        Whether to use cross-validation for more robust estimates
    
    Returns:
    --------
    dict : Dictionary containing test results
    """
    np.random.seed(random_state)
    
    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Default XGBoost parameters if none provided
    if best_params is None:
        best_params = {
            'n_estimators': 200,
            'max_depth': 5,
            'learning_rate': 0.1,
            'subsample': 0.9,
            'colsample_bytree': 0.9,
            'reg_alpha': 0.1,
            'reg_lambda': 0.1,
            'min_child_weight': 3,
            'gamma': 0.1
        }
    
    # Create base model with best parameters
    base_model_params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'random_state': random_state,
        'n_jobs': -1,
        'verbosity': 0,
        **best_params
    }
    
    # Fit original model and get baseline metrics
    original_model = xgb.XGBClassifier(**base_model_params)
    original_model.fit(X_train_scaled, y_train)
    
    # Original predictions and metrics
    y_pred_original = original_model.predict(X_test_scaled)
    y_proba_original = original_model.predict_proba(X_test_scaled)[:, 1]
    
    # Calculate multiple metrics for original model
    original_metrics = {
        'accuracy': accuracy_score(y_test, y_pred_original),
        'auc': roc_auc_score(y_test, y_proba_original),
        'precision': precision_score(y_test, y_pred_original, zero_division=0),
        'recall': recall_score(y_test, y_pred_original, zero_division=0),
        'f1': f1_score(y_test, y_pred_original, zero_division=0),
        'log_loss': log_loss(y_test, y_proba_original)
    }
    
    # Cross-validation score for original model (if requested)
    if use_cv:
        tscv = TimeSeriesSplit(n_splits=3)  # Reduced splits for speed
        cv_scores = []
        for train_idx, val_idx in tscv.split(X_train_scaled):
            X_cv_train, X_cv_val = X_train_scaled[train_idx], X_train_scaled[val_idx]
            y_cv_train, y_cv_val = y_train.iloc[train_idx], y_train.iloc[val_idx]
            
            cv_model = xgb.XGBClassifier(**base_model_params)
            cv_model.fit(X_cv_train, y_cv_train)
            cv_proba = cv_model.predict_proba(X_cv_val)[:, 1]
            cv_scores.append(roc_auc_score(y_cv_val, cv_proba))
        
        original_metrics['cv_auc'] = np.mean(cv_scores)
        original_metrics['cv_auc_std'] = np.std(cv_scores)
    
    # Initialize arrays to store permutation results
    permuted_metrics = {metric: [] for metric in original_metrics.keys() if not metric.endswith('_std')}
    
    print(f"Running {n_permutations} permutations for XGBoost model...")
    
    # Perform permutation test
    for i in range(n_permutations):
        try:
            # Shuffle the training labels
            y_train_permuted = shuffle(y_train, random_state=random_state + i)
            
            # Train model on permuted data
            permuted_model = xgb.XGBClassifier(**base_model_params)
            permuted_model.fit(X_train_scaled, y_train_permuted)
            
            # Make predictions on original test set
            y_pred_permuted = permuted_model.predict(X_test_scaled)
            y_proba_permuted = permuted_model.predict_proba(X_test_scaled)[:, 1]
            
            # Calculate metrics for permuted model
            permuted_metrics['accuracy'].append(accuracy_score(y_test, y_pred_permuted))
            permuted_metrics['auc'].append(roc_auc_score(y_test, y_proba_permuted))
            permuted_metrics['precision'].append(precision_score(y_test, y_pred_permuted, zero_division=0))
            permuted_metrics['recall'].append(recall_score(y_test, y_pred_permuted, zero_division=0))
            permuted_metrics['f1'].append(f1_score(y_test, y_pred_permuted, zero_division=0))
            permuted_metrics['log_loss'].append(log_loss(y_test, y_proba_permuted))
            
            # Cross-validation for permuted model (if requested and occasionally)
            if use_cv and i % 50 == 0:  # Only every 50th iteration for speed
                cv_scores_perm = []
                for train_idx, val_idx in tscv.split(X_train_scaled):
                    X_cv_train, X_cv_val = X_train_scaled[train_idx], X_train_scaled[val_idx]
                    y_cv_train, y_cv_val = y_train_permuted.iloc[train_idx], y_train_permuted.iloc[val_idx]
                    
                    cv_model_perm = xgb.XGBClassifier(**base_model_params)
                    cv_model_perm.fit(X_cv_train, y_cv_train)
                    cv_proba_perm = cv_model_perm.predict_proba(X_cv_val)[:, 1]
                    cv_scores_perm.append(roc_auc_score(y_cv_val, cv_proba_perm))
                
                if 'cv_auc' in permuted_metrics:
                    permuted_metrics['cv_auc'].append(np.mean(cv_scores_perm))
                else:
                    permuted_metrics['cv_auc'] = [np.mean(cv_scores_perm)]
            
        except Exception as e:
            print(f"Error in permutation {i}: {e}")
            # Add NaN values to maintain array lengths
            for metric in permuted_metrics.keys():
                if metric != 'cv_auc' or len(permuted_metrics[metric]) < i:
                    permuted_metrics[metric].append(np.nan)
    
    # Convert to numpy arrays and remove NaN values
    for metric in permuted_metrics.keys():
        permuted_metrics[metric] = np.array(permuted_metrics[metric])
        permuted_metrics[metric] = permuted_metrics[metric][~np.isnan(permuted_metrics[metric])]
    
    # Calculate p-values and effect sizes
    results = {'original_metrics': original_metrics}
    
    for metric, values in permuted_metrics.items():
        if len(values) > 0:
            original_value = original_metrics[metric]
            
            # P-value (one-tailed test - testing if original is better than random)
            if metric == 'log_loss':  # Lower is better for log_loss
                p_value = np.mean(values <= original_value)
            else:  # Higher is better for other metrics
                p_value = np.mean(values >= original_value)
            
            # Effect size (standardized difference)
            if np.std(values) > 0:
                effect_size = (original_value - np.mean(values)) / np.std(values)
            else:
                effect_size = 0
            
            results[f'permuted_{metric}'] = values
            results[f'p_value_{metric}'] = p_value
            results[f'effect_size_{metric}'] = effect_size
            results[f'permuted_mean_{metric}'] = np.mean(values)
            results[f'permuted_std_{metric}'] = np.std(values)
    
    return results

def plot_permutation_results_xgboost(results, stock_name, save_path=None):
    """
    Plot the results of XGBoost permutation test with multiple metrics.
    """
    # Select key metrics to plot
    metrics_to_plot = ['accuracy', 'auc', 'f1', 'precision']
    available_metrics = [m for m in metrics_to_plot if f'permuted_{m}' in results]
    
    n_metrics = len(available_metrics)
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    axes = axes.flatten()
    
    colors = ['lightblue', 'lightcoral', 'lightgreen', 'lightyellow']
    
    for i, metric in enumerate(available_metrics[:4]):  # Limit to 4 plots
        if i >= len(axes):
            break
            
        ax = axes[i]
        
        # Plot histogram of permuted results
        permuted_values = results[f'permuted_{metric}']
        original_value = results['original_metrics'][metric]
        p_value = results[f'p_value_{metric}']
        effect_size = results[f'effect_size_{metric}']
        
        ax.hist(permuted_values, bins=50, alpha=0.7, color=colors[i], 
                label='Permuted Distribution', density=True)
        ax.axvline(original_value, color='red', linestyle='--', linewidth=2, 
                   label=f'Original {metric.upper()}: {original_value:.4f}')
        ax.axvline(np.mean(permuted_values), color='green', linestyle='-', linewidth=2,
                   label=f'Permuted Mean: {np.mean(permuted_values):.4f}')
        
        ax.set_xlabel(metric.upper())
        ax.set_ylabel('Density')
        ax.set_title(f'{stock_name} - {metric.upper()} Permutation Test\n'
                     f'P-value: {p_value:.4f}, Effect Size: {effect_size:.2f}')
        ax.legend()
        ax.grid(True, alpha=0.3)
    
    # Hide unused subplots
    for i in range(len(available_metrics), len(axes)):
        axes[i].set_visible(False)
    
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"XGBoost permutation test plot saved to {save_path}")
    
    plt.show()

def create_significance_summary_plot(permutation_results_df, save_path=None):
    """
    Create summary plots of statistical significance across all stocks.
    """
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    
    # P-value distributions
    metrics = ['accuracy', 'auc', 'f1', 'precision']
    
    for i, metric in enumerate(metrics):
        ax = axes[i//2, i%2]
        p_col = f'P_Value_{metric.upper()}'
        
        if p_col in permutation_results_df.columns:
            p_values = permutation_results_df[p_col].dropna()
            
            ax.hist(p_values, bins=20, alpha=0.7, edgecolor='black')
            ax.axvline(0.05, color='red', linestyle='--', linewidth=2, label='α = 0.05')
            ax.axvline(0.01, color='orange', linestyle='--', linewidth=2, label='α = 0.01')
            
            significant_05 = sum(p_values < 0.05)
            significant_01 = sum(p_values < 0.01)
            
            ax.set_xlabel('P-value')
            ax.set_ylabel('Frequency')
            ax.set_title(f'{metric.upper()} P-values Distribution\n'
                        f'Significant (p<0.05): {significant_05}/{len(p_values)} stocks\n'
                        f'Highly significant (p<0.01): {significant_01}/{len(p_values)} stocks')
            ax.legend()
            ax.grid(True, alpha=0.3)
    
    plt.tight_layout()
    
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"Significance summary plot saved to {save_path}")
    
    plt.show()

# Main execution
if __name__ == "__main__":
    # Configuration
    N_PERMUTATIONS = 500  # Reduced for XGBoost (slower than logistic regression)
    RANDOM_STATE = 42
    USE_CV = True  # Set to False for faster execution
    
    # Paths
    input_folder = "data/processed/stock_data"
    summary_folder = "summary"
    model_folder = os.path.join(summary_folder, "xgboost2")
    permutation_folder = os.path.join(summary_folder, "xgboost_permutation_tests2")
    os.makedirs(permutation_folder, exist_ok=True)
    
    summary_results = []
    permutation_results = []
    
    # Process each stock file
    for file_path in glob(os.path.join(input_folder, "*.csv")):
        stock_name = os.path.basename(file_path).replace("_features.csv", "")
        print(f"\n{'='*60}")
        print(f"Processing {stock_name}")
        print(f"{'='*60}")
        
        try:
            # Load data
            df = pd.read_csv(file_path)
            df = df.tail(1000)
            df.dropna(inplace=True)
            
            # Create binary target: 1 if price goes up tomorrow, 0 if down
            df['Direction'] = (df['Close'].shift(-1) > df['Close']).astype(int)
            df.dropna(inplace=True)
            
            # Features
            X = df.drop(columns=[
                "Date","Close","Target","Direction",
                "High","Low","Open","High_lag1","Low_lag1","Open_lag1"
            ])
            y = df['Direction']
            
            # Split
            train_size = int(len(X) * 0.8)
            X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
            y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]
            
            print(f"Train size: {len(X_train)}, Test size: {len(X_test)}")
            print(f"Features: {X.shape[1]}")
            print(f"Class distribution - Train: {y_train.value_counts().to_dict()}")
            print(f"Class distribution - Test: {y_test.value_counts().to_dict()}")
            
            # Load best parameters if available
            params_path = os.path.join(model_folder, f"{stock_name}_best_params.pkl")
            if os.path.exists(params_path):
                best_params = joblib.load(params_path)
                print(f"Loaded best parameters from {params_path}")
            else:
                best_params = None
                print("Using default parameters")
            
            # Perform Monte Carlo permutation test
            results = monte_carlo_permutation_test_xgboost(
                X_train, X_test, y_train, y_test,
                best_params=best_params,
                n_permutations=N_PERMUTATIONS,
                random_state=RANDOM_STATE,
                use_cv=USE_CV
            )
            
            # Print results
            print(f"\n--- XGBOOST PERMUTATION TEST RESULTS ---")
            original_metrics = results['original_metrics']
            
            for metric, value in original_metrics.items():
                if not metric.endswith('_std'):
                    print(f"Original {metric.upper()}: {value:.4f}")
                    
                    if f'p_value_{metric}' in results:
                        p_val = results[f'p_value_{metric}']
                        effect_size = results[f'effect_size_{metric}']
                        perm_mean = results[f'permuted_mean_{metric}']
                        perm_std = results[f'permuted_std_{metric}']
                        
                        print(f"  Permuted Mean ± Std: {perm_mean:.4f} ± {perm_std:.4f}")
                        print(f"  P-value: {p_val:.4f}")
                        print(f"  Effect Size: {effect_size:.4f}")
                        print(f"  Significant (p<0.05): {'YES' if p_val < 0.05 else 'NO'}")
                        print()
            
            # Create and save plots
            plot_path = os.path.join(permutation_folder, f"{stock_name}_xgboost_permutation_test.png")
            plot_permutation_results_xgboost(results, stock_name, plot_path)
            
            # Store results for summary
            result_dict = {
                "Stock": stock_name,
                "N_Permutations": N_PERMUTATIONS,
                "Train_Size": len(X_train),
                "Test_Size": len(X_test),
                "N_Features": X.shape[1]
            }
            
            # Add original metrics and statistical results
            for metric, value in original_metrics.items():
                if not metric.endswith('_std'):
                    result_dict[f'Original_{metric.upper()}'] = value
                    
                    if f'p_value_{metric}' in results:
                        result_dict[f'P_Value_{metric.upper()}'] = results[f'p_value_{metric}']
                        result_dict[f'Effect_Size_{metric.upper()}'] = results[f'effect_size_{metric}']
                        result_dict[f'Permuted_Mean_{metric.upper()}'] = results[f'permuted_mean_{metric}']
                        result_dict[f'Permuted_Std_{metric.upper()}'] = results[f'permuted_std_{metric}']
                        result_dict[f'Significant_{metric.upper()}'] = results[f'p_value_{metric}'] < 0.05
            
            permutation_results.append(result_dict)
            
            # Also store in original summary format
            summary_results.append({
                "Stock": stock_name,
                "Accuracy": original_metrics['accuracy'],
                "AUC": original_metrics['auc'],
                "F1": original_metrics['f1'],
                "Precision": original_metrics['precision']
            })
            
        except Exception as e:
            print(f"Error processing {stock_name}: {str(e)}")
            continue
    
    # Save detailed permutation test results
    permutation_df = pd.DataFrame(permutation_results)
    permutation_file = os.path.join(summary_folder, "xgboost_permutation_test_results.csv")
    permutation_df.to_csv(permutation_file, index=False)
    print(f"\nXGBoost permutation test results saved to {permutation_file}")
    
    # Save summary results
    summary_df = pd.DataFrame(summary_results)
    summary_file = os.path.join(summary_folder, "xgboost_model_summary_with_permutation.csv")
    summary_df.to_csv(summary_file, index=False)
    print(f"Summary saved to {summary_file}")
    
    # Create significance summary plots
    significance_plot_path = os.path.join(permutation_folder, "significance_summary_xgboost.png")
    create_significance_summary_plot(permutation_df, significance_plot_path)
    
    # Print comprehensive summary
    print(f"\n{'='*80}")
    print("COMPREHENSIVE XGBOOST PERMUTATION TEST SUMMARY")
    print(f"{'='*80}")
    print(f"Total stocks processed: {len(permutation_results)}")
    print(f"Number of permutations per stock: {N_PERMUTATIONS}")
    
    # Significance summary for each metric
    metrics = ['ACCURACY', 'AUC', 'F1', 'PRECISION']
    for metric in metrics:
        p_col = f'P_Value_{metric}'
        if p_col in permutation_df.columns:
            significant_05 = sum(permutation_df[p_col] < 0.05)
            significant_01 = sum(permutation_df[p_col] < 0.01)
            mean_p_value = permutation_df[p_col].mean()
            mean_effect_size = permutation_df[f'Effect_Size_{metric}'].mean()
            
            print(f"\n{metric}:")
            print(f"  Significant stocks (p < 0.05): {significant_05}/{len(permutation_results)} ({100*significant_05/len(permutation_results):.1f}%)")
            print(f"  Highly significant stocks (p < 0.01): {significant_01}/{len(permutation_results)} ({100*significant_01/len(permutation_results):.1f}%)")
            print(f"  Mean p-value: {mean_p_value:.4f}")
            print(f"  Mean effect size: {mean_effect_size:.4f}")
    
    # Top performing stocks
    print(f"\nTOP 5 STOCKS BY AUC P-VALUE:")
    if 'P_Value_AUC' in permutation_df.columns:
        top_auc = permutation_df.nsmallest(5, 'P_Value_AUC')[['Stock', 'Original_AUC', 'P_Value_AUC', 'Effect_Size_AUC']]
        print(top_auc.to_string(index=False))
    
    print(f"\nTOP 5 STOCKS BY ACCURACY P-VALUE:")
    if 'P_Value_ACCURACY' in permutation_df.columns:
        top_acc = permutation_df.nsmallest(5, 'P_Value_ACCURACY')[['Stock', 'Original_ACCURACY', 'P_Value_ACCURACY', 'Effect_Size_ACCURACY']]
        print(top_acc.to_string(index=False))
    
    print(f"\nXGBoost permutation testing completed!")
    print(f"Results saved to: {permutation_file}")
    print(f"Plots saved to: {permutation_folder}")
# Out:
# ============================================================
# Processing AAPL_daily
# ============================================================
# Train size: 800, Test size: 200
# Features: 17
# Class distribution - Train: {1: 423, 0: 377}
# Class distribution - Test: {1: 108, 0: 92}
# Loaded best parameters from summary\xgboost2\AAPL_daily_best_params.pkl
# Running 500 permutations for XGBoost model...
#
# --- XGBOOST PERMUTATION TEST RESULTS ---
# Original ACCURACY: 0.4950
#   Permuted Mean ± Std: 0.5078 ± 0.0347
#   P-value: 0.6560
#   Effect Size: -0.3699
#   Significant (p<0.05): NO
#
# Original AUC: 0.4584
#   Permuted Mean ± Std: 0.5010 ± 0.0411
#   P-value: 0.8520
#   Effect Size: -1.0371
#   Significant (p<0.05): NO
#
# Original PRECISION: 0.5271
#   Permuted Mean ± Std: 0.5415 ± 0.0372
#   P-value: 0.6520
#   Effect Size: -0.3863
#   Significant (p<0.05): NO
#
# Original RECALL: 0.6296
#   Permuted Mean ± Std: 0.6046 ± 0.1628
#   P-value: 0.4700
#   Effect Size: 0.1534
#   Significant (p<0.05): NO
#
# Original F1: 0.5738
#   Permuted Mean ± Std: 0.5593 ± 0.0833
#   P-value: 0.5160
#   Effect Size: 0.1741
#   Significant (p<0.05): NO
#
# Original LOG_LOSS: 0.7286
#   Permuted Mean ± Std: 0.7165 ± 0.0191
#   P-value: 0.7740
#   Effect Size: 0.6328
#   Significant (p<0.05): NO
#
# Original CV_AUC: 0.4928
#   Permuted Mean ± Std: 0.4928 ± 0.0264
#   P-value: 0.4000
#   Effect Size: -0.0001
#   Significant (p<0.05): NO
#
# XGBoost permutation test plot saved to summary\xgboost_permutation_tests2\AAPL_daily_xgboost_permutation_test.png
# ============================================================
# Processing GE_daily
# ============================================================
# Train size: 800, Test size: 200
# Features: 17
# Class distribution - Train: {1: 437, 0: 363}
# Class distribution - Test: {1: 116, 0: 84}
# Loaded best parameters from summary\xgboost2\GE_daily_best_params.pkl
# Running 500 permutations for XGBoost model...
#
# --- XGBOOST PERMUTATION TEST RESULTS ---
# Original ACCURACY: 0.5650
#   Permuted Mean ± Std: 0.5376 ± 0.0398
#   P-value: 0.3040
#   Effect Size: 0.6892
#   Significant (p<0.05): NO
#
# Original AUC: 0.4982
#   Permuted Mean ± Std: 0.5009 ± 0.0382
#   P-value: 0.5480
#   Effect Size: -0.0711
#   Significant (p<0.05): NO
#
# Original PRECISION: 0.5829
#   Permuted Mean ± Std: 0.5818 ± 0.0367
#   P-value: 0.4300
#   Effect Size: 0.0297
#   Significant (p<0.05): NO
#
# Original RECALL: 0.8793
#   Permuted Mean ± Std: 0.7386 ± 0.1987
#   P-value: 0.2620
#   Effect Size: 0.7082
#   Significant (p<0.05): NO
#
# Original F1: 0.7010
#   Permuted Mean ± Std: 0.6339 ± 0.1095
#   P-value: 0.2500
#   Effect Size: 0.6133
#   Significant (p<0.05): NO
#
# Original LOG_LOSS: 0.6893
#   Permuted Mean ± Std: 0.6941 ± 0.0126
#   P-value: 0.4000
#   Effect Size: -0.3779
#   Significant (p<0.05): NO
#
# Original CV_AUC: 0.4752
#   Permuted Mean ± Std: 0.5045 ± 0.0189
#   P-value: 1.0000
#   Effect Size: -1.5447
#   Significant (p<0.05): NO
#
# XGBoost permutation test plot saved to summary\xgboost_permutation_tests2\GE_daily_xgboost_permutation_test.png
# ============================================================
# Processing IBM_daily
# ============================================================
# Train size: 800, Test size: 200
# Features: 17
# Class distribution - Train: {1: 436, 0: 364}
# Class distribution - Test: {1: 110, 0: 90}
# Loaded best parameters from summary\xgboost2\IBM_daily_best_params.pkl
# Running 500 permutations for XGBoost model...
#
# --- XGBOOST PERMUTATION TEST RESULTS ---
# Original ACCURACY: 0.5600
#   Permuted Mean ± Std: 0.5232 ± 0.0339
#   P-value: 0.1480
#   Effect Size: 1.0848
#   Significant (p<0.05): NO
#
# Original AUC: 0.5431
#   Permuted Mean ± Std: 0.5001 ± 0.0408
#   P-value: 0.1520
#   Effect Size: 1.0530
#   Significant (p<0.05): NO
#
# Original PRECISION: 0.5611
#   Permuted Mean ± Std: 0.5505 ± 0.0270
#   P-value: 0.2320
#   Effect Size: 0.3927
#   Significant (p<0.05): NO
#
# Original RECALL: 0.9182
#   Permuted Mean ± Std: 0.7330 ± 0.1858
#   P-value: 0.1580
#   Effect Size: 0.9968
#   Significant (p<0.05): NO
#
# Original F1: 0.6966
#   Permuted Mean ± Std: 0.6165 ± 0.0878
#   P-value: 0.1160
#   Effect Size: 0.9119
#   Significant (p<0.05): NO
#
# Original LOG_LOSS: 0.6909
#   Permuted Mean ± Std: 0.7001 ± 0.0116
#   P-value: 0.2040
#   Effect Size: -0.7897
#   Significant (p<0.05): NO
#
# Original CV_AUC: 0.5459
#   Permuted Mean ± Std: 0.5047 ± 0.0192
#   P-value: 0.0000
#   Effect Size: 2.1496
#   Significant (p<0.05): YES
#
# XGBoost permutation test plot saved to summary\xgboost_permutation_tests2\IBM_daily_xgboost_permutation_test.png
# ============================================================
# Processing JNJ_daily
# ============================================================
# Train size: 800, Test size: 200
# Features: 17
# Class distribution - Train: {1: 400, 0: 400}
# Class distribution - Test: {1: 110, 0: 90}
# Loaded best parameters from summary\xgboost2\JNJ_daily_best_params.pkl
# Running 500 permutations for XGBoost model...
#
# --- XGBOOST PERMUTATION TEST RESULTS ---
# Original ACCURACY: 0.5800
#   Permuted Mean ± Std: 0.4982 ± 0.0334
#   P-value: 0.0100
#   Effect Size: 2.4468
#   Significant (p<0.05): YES
#
# Original AUC: 0.5656
#   Permuted Mean ± Std: 0.4994 ± 0.0407
#   P-value: 0.0640
#   Effect Size: 1.6257
#   Significant (p<0.05): NO
#
# Original PRECISION: 0.6585
#   Permuted Mean ± Std: 0.5487 ± 0.0342
#   P-value: 0.0020
#   Effect Size: 3.2130
#   Significant (p<0.05): YES
#
# Original RECALL: 0.4909
#   Permuted Mean ± Std: 0.4984 ± 0.0758
#   P-value: 0.5500
#   Effect Size: -0.0986
#   Significant (p<0.05): NO
#
# Original F1: 0.5625
#   Permuted Mean ± Std: 0.5195 ± 0.0490
#   P-value: 0.1980
#   Effect Size: 0.8767
#   Significant (p<0.05): NO
#
# Original LOG_LOSS: 0.6988
#   Permuted Mean ± Std: 0.7040 ± 0.0106
#   P-value: 0.3200
#   Effect Size: -0.4966
#   Significant (p<0.05): NO
#
# Original CV_AUC: 0.5774
#   Permuted Mean ± Std: 0.5066 ± 0.0200
#   P-value: 0.0000
#   Effect Size: 3.5401
#   Significant (p<0.05): YES
#
# XGBoost permutation test plot saved to summary\xgboost_permutation_tests2\JNJ_daily_xgboost_permutation_test.png
# ============================================================
# Processing MSFT_daily
# ============================================================
# Train size: 800, Test size: 200
# Features: 17
# Class distribution - Train: {1: 409, 0: 391}
# Class distribution - Test: {1: 113, 0: 87}
# Loaded best parameters from summary\xgboost2\MSFT_daily_best_params.pkl
# Running 500 permutations for XGBoost model...
#
# --- XGBOOST PERMUTATION TEST RESULTS ---
# Original ACCURACY: 0.4500
#   Permuted Mean ± Std: 0.5085 ± 0.0389
#   P-value: 0.9360
#   Effect Size: -1.5036
#   Significant (p<0.05): NO
#
# Original AUC: 0.4399
#   Permuted Mean ± Std: 0.5010 ± 0.0396
#   P-value: 0.9280
#   Effect Size: -1.5428
#   Significant (p<0.05): NO
#
# Original PRECISION: 0.5138
#   Permuted Mean ± Std: 0.5655 ± 0.0328
#   P-value: 0.9360
#   Effect Size: -1.5768
#   Significant (p<0.05): NO
#
# Original RECALL: 0.4956
#   Permuted Mean ± Std: 0.5554 ± 0.1573
#   P-value: 0.6480
#   Effect Size: -0.3805
#   Significant (p<0.05): NO
#
# Original F1: 0.5045
#   Permuted Mean ± Std: 0.5494 ± 0.0906
#   P-value: 0.7160
#   Effect Size: -0.4951
#   Significant (p<0.05): NO
#
# Original LOG_LOSS: 0.7151
#   Permuted Mean ± Std: 0.7021 ± 0.0124
#   P-value: 0.8520
#   Effect Size: 1.0441
#   Significant (p<0.05): NO
#
# Original CV_AUC: 0.5463
#   Permuted Mean ± Std: 0.4979 ± 0.0209
#   P-value: 0.0000
#   Effect Size: 2.3166
#   Significant (p<0.05): YES
#
# XGBoost permutation test plot saved to summary\xgboost_permutation_tests2\MSFT_daily_xgboost_permutation_test.png
# XGBoost permutation test results saved to summary\xgboost_permutation_test_results.csv
# Summary saved to summary\xgboost_model_summary_with_permutation.csv
# Significance summary plot saved to summary\xgboost_permutation_tests2\significance_summary_xgboost.png
# ================================================================================
# COMPREHENSIVE XGBOOST PERMUTATION TEST SUMMARY
# ================================================================================
# Total stocks processed: 5
# Number of permutations per stock: 500
#
# ACCURACY:
#   Significant stocks (p < 0.05): 1/5 (20.0%)
#   Highly significant stocks (p < 0.01): 0/5 (0.0%)
#   Mean p-value: 0.4108
#   Mean effect size: 0.4695
#
# AUC:
#   Significant stocks (p < 0.05): 0/5 (0.0%)
#   Highly significant stocks (p < 0.01): 0/5 (0.0%)
#   Mean p-value: 0.5088
#   Mean effect size: 0.0055
#
# F1:
#   Significant stocks (p < 0.05): 0/5 (0.0%)
#   Highly significant stocks (p < 0.01): 0/5 (0.0%)
#   Mean p-value: 0.3592
#   Mean effect size: 0.4162
#
# PRECISION:
#   Significant stocks (p < 0.05): 1/5 (20.0%)
#   Highly significant stocks (p < 0.01): 1/5 (20.0%)
#   Mean p-value: 0.4504
#   Mean effect size: 0.3345
#
# TOP 5 STOCKS BY AUC P-VALUE:
#      Stock  Original_AUC  P_Value_AUC  Effect_Size_AUC
#  JNJ_daily      0.565556        0.064         1.625717
#  IBM_daily      0.543131        0.152         1.053003
#   GE_daily      0.498153        0.548        -0.071141
# AAPL_daily      0.458434        0.852        -1.037065
# MSFT_daily      0.439935        0.928        -1.542791
#
# TOP 5 STOCKS BY ACCURACY P-VALUE:
#      Stock  Original_ACCURACY  P_Value_ACCURACY  Effect_Size_ACCURACY
#  JNJ_daily              0.580             0.010              2.446825
#  IBM_daily              0.560             0.148              1.084809
#   GE_daily              0.565             0.304              0.689237
# AAPL_daily              0.495             0.656             -0.369945
# MSFT_daily              0.450             0.936             -1.503644
#
# XGBoost permutation testing completed!
# Results saved to: summary\xgboost_permutation_test_results.csv
# Plots saved to: summary\xgboost_permutation_tests2
